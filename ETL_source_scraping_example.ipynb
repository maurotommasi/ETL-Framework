# %%
from ETL import ETL
from modules.Transformation import Transformation
from modules.DataSource import DataSourceConfig
from modules.Encoder import EncoderConfig
from modules.Loader import LoaderConfig
from ETL import FlowConfig

# Encoder Config

tags = ["tr", "td"]

# Datasource Config

url = "https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"
url2 = "http://www.google.com"
url3 = "https://edition.cnn.com"

# Flow Config

flow_config = FlowConfig()

flow1 = flow_config.create_flow(
    ID_datasource=f'Website Scraping {url}',
    ID_encoder='Basic HTML Tags',
    ID_ingestion=f'Scraping Ingestion for {url}',
    ID_control='1 Hour Update',
    ID_loader=f'Json File Loader on export/{url[7:]}.json')

flow2 = flow_config.create_flow(
    ID_datasource=f'Website Scraping {url2}',
    ID_encoder='Basic HTML Tags',
    ID_ingestion=f'Scraping Ingestion for {url2}',
    ID_control='1 Hour Update',
    ID_loader=f'Json File Loader on export/{url2[7:]}.json',
    ID_process="Transformation Basic for HTML")

flow3 = flow_config.create_flow(
    ID_datasource=f'Website Scraping {url3}',
    ID_encoder='Basic HTML Tags',
    ID_ingestion=f'Scraping Ingestion for {url3}',
    ID_control='1 Hour Update',
    ID_loader=f'Json File Loader on export/{url3[7:]}.json')

flow_config.add_flow(flow1)
flow_config.add_flow(flow2)
flow_config.add_flow(flow3) # No transformation

# Pipeline Object Creation

pipeline = ETL("ETL Pipeline")

# Create Pipeline Elements

## Flow 1

pipeline.create_datasource(f'Website Scraping {url}', DataSourceConfig().scraping_source_config(url))
pipeline.create_encoder('Basic HTML Tags', EncoderConfig().html_encoder_config(tags, tags))
pipeline.create_ingestion(f'Scraping Ingestion for {url}')
pipeline.create_process("Transformation Basic for HTML", [Transformation().default_scraping_to_pivot_table])
pipeline.create_control('1 Hour Update',3600,3600)
pipeline.create_loader(f'Json File Loader on export/{url[7:]}.json', LoaderConfig().json_file_loader(f'export/wikipedia.json'))

## Flow 2

pipeline.create_datasource(f'Website Scraping {url2}', DataSourceConfig().scraping_source_config(url2))
pipeline.create_ingestion(f'Scraping Ingestion for {url2}')
pipeline.create_loader(f'Json File Loader on export/{url2[7:]}.json', LoaderConfig().json_file_loader(f'export/{url2[7:]}.json'))

## Flow 3

pipeline.create_datasource(f'Website Scraping {url3}', DataSourceConfig().scraping_source_config(url3))
pipeline.create_ingestion(f'Scraping Ingestion for {url3}')
pipeline.create_loader(f'Json File Loader on export/{url3[7:]}.json', LoaderConfig().json_file_loader(f'export/{url3[7:]}.json'))

# Set Pipeline flow

pipeline.set_flow(flow_config.get_flow_config())

# Pipeline Start 

pipeline.start()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\development\Documents\GitHub\ETL\ETL_source_scraping_example.ipynb Cell 1 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/development/Documents/GitHub/ETL/ETL_source_scraping_example.ipynb#W0sZmlsZQ%3D%3D?line=56'>57</a> pipeline.create_encoder('Basic HTML Tags', EncoderConfig().html_encoder_config(tags, tags))
#      <a href='vscode-notebook-cell:/c%3A/Users/development/Documents/GitHub/ETL/ETL_source_scraping_example.ipynb#W0sZmlsZQ%3D%3D?line=57'>58</a> pipeline.create_ingestion(f'Scraping Ingestion for {url}')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/development/Documents/GitHub/ETL/ETL_source_scraping_example.ipynb#W0sZmlsZQ%3D%3D?line=58'>59</a> pipeline.create_process("Transformation Basic for HTML", [Transformation().scraping_to_pivot_table])
#      <a href='vscode-notebook-cell:/c%3A/Users/development/Documents/GitHub/ETL/ETL_source_scraping_example.ipynb#W0sZmlsZQ%3D%3D?line=59'>60</a> pipeline.create_control('1 Hour Update',3600,3600)
#      <a href='vscode-notebook-cell:/c%3A/Users/development/Documents/GitHub/ETL/ETL_source_scraping_example.ipynb#W0sZmlsZQ%3D%3D?line=60'>61</a> pipeline.create_loader(f'Json File Loader on export/{url[7:]}.json', LoaderConfig().json_file_loader(f'export/wikipedia.json'))
#
# AttributeError: 'Transformation' object has no attribute 'scraping_to_pivot_table'

# %%
import pandas as pd
from modules.Utils import Utils

df = pd.DataFrame(Utils().read_json('export/wikipedia.json'))

df[0:500]
# Out:
#                                                   text url  \
# 0
# 1
# 2    $50–100 billion$25–50 billion$5–25 billion< $5...
# 3    $750 billion – $1 trillion$500–750 billion$250...
# 4    (Nominal, Atlas method) per capita(PPP) per ca...
# ..                                                 ...  ..
# 495                                             53,954
# 496                                            539,223
# 497                                             54,622
# 498                                                541
# 499                                                547
#
#                       date_time  \
# 0    2023-11-01 23:27:43.753182
# 1    2023-11-01 23:27:43.763181
# 2    2023-11-01 23:27:43.763181
# 3    2023-11-01 23:27:43.763181
# 4    2023-11-01 23:27:43.772182
# ..                          ...
# 495  2023-11-01 23:27:43.767150
# 496  2023-11-01 23:27:43.764173
# 497  2023-11-01 23:27:43.768150
# 498  2023-11-01 23:27:43.772182
# 499  2023-11-01 23:27:43.772182
#
#                                           ingestion_ID  \
# 0    Scraping Ingestion for https://web.archive.org...
# 1    Scraping Ingestion for https://web.archive.org...
# 2    Scraping Ingestion for https://web.archive.org...
# 3    Scraping Ingestion for https://web.archive.org...
# 4    Scraping Ingestion for https://web.archive.org...
# ..                                                 ...
# 495  Scraping Ingestion for https://web.archive.org...
# 496  Scraping Ingestion for https://web.archive.org...
# 497  Scraping Ingestion for https://web.archive.org...
# 498  Scraping Ingestion for https://web.archive.org...
# 499  Scraping Ingestion for https://web.archive.org...
#
#                                                     td tr
# 0
# 1
# 2    $50–100 billion$25–50 billion$5–25 billion< $5...
# 3    $750 billion – $1 trillion$500–750 billion$250...
# 4    (Nominal, Atlas method) per capita(PPP) per ca...
# ..                                                 ... ..
# 495                                             53,954
# 496                                            539,223
# 497                                             54,622
# 498                                                541
# 499                                                547
#
# [500 rows x 6 columns]

# %%
pd.DataFrame(Utils().read_json('export/edition.cnn.com.json'))
# Out:
#     original_tag mapping_tag  \
# 0             h2          h2
# 1             h2          h2
# 2             h2          h2
# 3             h2          h2
# 4             h2          h2
# ..           ...         ...
# 475          img         img
# 476          img         img
# 477          img         img
# 478          img         img
# 479          img         img
#
#                                                   text  \
# 0    Hundreds of Gazans and foreign nationals leave...
# 1                                     More top stories
# 2                                             Featured
# 3                                    Featured Sections
# 4                                         CNN Business
# ..                                                 ...
# 475  Gyasi directs actor Angela Basset for the 2024...
# 476  Simit is the most popular street food in Istan...
# 477                            hornussen story gallery
# 478                                     SAOTA beyond 1
# 479  West Antarctica — home to the Thwaites Glacier...
#
#                                                    url  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 475  https://media.cnn.com/api/v1/images/stellar/pr...
# 476  https://media.cnn.com/api/v1/images/stellar/pr...
# 477  https://media.cnn.com/api/v1/images/stellar/pr...
# 478  https://media.cnn.com/api/v1/images/stellar/pr...
# 479  https://media.cnn.com/api/v1/images/stellar/pr...
#
#                       date_time  \
# 0    2023-11-01 19:37:35.705864
# 1    2023-11-01 19:37:35.705864
# 2    2023-11-01 19:37:35.705864
# 3    2023-11-01 19:37:35.706878
# 4    2023-11-01 19:37:35.706878
# ..                          ...
# 475  2023-11-01 19:37:35.721895
# 476  2023-11-01 19:37:35.721895
# 477  2023-11-01 19:37:35.721895
# 478  2023-11-01 19:37:35.721895
# 479  2023-11-01 19:37:35.721895
#
#                                        ingestion_ID
# 0    Scraping Ingestion for https://edition.cnn.com
# 1    Scraping Ingestion for https://edition.cnn.com
# 2    Scraping Ingestion for https://edition.cnn.com
# 3    Scraping Ingestion for https://edition.cnn.com
# 4    Scraping Ingestion for https://edition.cnn.com
# ..                                              ...
# 475  Scraping Ingestion for https://edition.cnn.com
# 476  Scraping Ingestion for https://edition.cnn.com
# 477  Scraping Ingestion for https://edition.cnn.com
# 478  Scraping Ingestion for https://edition.cnn.com
# 479  Scraping Ingestion for https://edition.cnn.com
#
# [480 rows x 6 columns]

# %%
pd.DataFrame(Utils().read_json('export/www.mendo.care.json'))
# Out:
#                         text  \
# 0
# 1
# 2
# 3
# 4
# ..                       ...
# 256  fashion and accessories
# 257          info@mendo.care
# 258          info@mendo.care
# 259     terms and conditions
# 260                        →
#
#                                                    url  \
# 0    data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 1    https://mendo.care/wp-content/uploads/2023/03/...
# 2
# 3    data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 4    data:image/svg+xml,%3Csvg%20xmlns='http://www....
# ..                                                 ...
# 256  https://www.mendo.care/wp-content/uploads/2023...
# 257                             mailto:info@mendo.care
# 258                             mailto:info@mendo.care
# 259        https://www.mendo.care/terms-and-conditions
# 260                                javascript:void(0);
#
#                       date_time                                  ingestion_ID  \
# 0    2023-11-01 19:37:35.892864  Scraping Ingestion for http://www.mendo.care
# 1    2023-11-01 19:37:35.892864  Scraping Ingestion for http://www.mendo.care
# 2    2023-11-01 19:37:35.883895  Scraping Ingestion for http://www.mendo.care
# 3    2023-11-01 19:37:35.892864  Scraping Ingestion for http://www.mendo.care
# 4    2023-11-01 19:37:35.891866  Scraping Ingestion for http://www.mendo.care
# ..                          ...                                           ...
# 256  2023-11-01 19:37:35.892864  Scraping Ingestion for http://www.mendo.care
# 257  2023-11-01 19:37:35.886866  Scraping Ingestion for http://www.mendo.care
# 258  2023-11-01 19:37:35.888866  Scraping Ingestion for http://www.mendo.care
# 259  2023-11-01 19:37:35.888866  Scraping Ingestion for http://www.mendo.care
# 260  2023-11-01 19:37:35.888866  Scraping Ingestion for http://www.mendo.care
#
#                         a h2 h3 h4 h5 h6                      img p
# 0
# 1
# 2
# 3
# 4
# ..                    ... .. .. .. .. ..                      ... ..
# 256                                       fashion and accessories
# 257       info@mendo.care
# 258       info@mendo.care
# 259  terms and conditions
# 260                     →
#
# [261 rows x 12 columns]
